# %% [markdown]
# # Time Series Analysis of Computer and Electronic Product Manufacturing (1972-2024)

# %% [markdown]
# ## Introduction
#
# This notebook analyzes the Industrial Production Index for Computer and Electronic Product Manufacturing (NAICS = 334) from the Federal Reserve Economic Data (FRED). This economic indicator measures the real output of the computer and electronics manufacturing sector and serves as an important gauge of technological production and innovation.

# %%
# Install required packages if needed
# install.packages(c("ggplot2", "forecast", "TSA", "tseries", "dplyr",
#                   "lubridate", "gridExtra", "MASS", "knitr", "lawstat",
#                   "FinTS", "ggthemes"))

# %%
suppressPackageStartupMessages({
  library(ggplot2)
  library(forecast)
  library(tseries)
  library(dplyr)
  library(lubridate)
  library(gridExtra)
  library(MASS)
  library(knitr)
  library(lawstat)
  library(FinTS)
  library(TSA)
})

# %%
# Plot settings
options(repr.plot.width = 20, repr.plot.height = 10)
theme_tsa <- function() {
  theme_minimal() +
    theme(
      plot.title = element_text(hjust = 0.5, face = "bold", size = 14),
      plot.subtitle = element_text(hjust = 0.5, size = 12),
      axis.title = element_text(face = "bold"),
      legend.position = "bottom",
      panel.grid.minor = element_line(color = "gray90"),
      panel.grid.major = element_line(color = "gray85")
    )
}

# %%
# loading the data and checking it for missing values
# and summary statistics, then printing the results

electronics_df <- read.csv("../data/computer_electronics_production.csv")
electronics_df$date <- as.Date(electronics_df$date)

cat("Dataset summary:\n")
print(summary(electronics_df))

cat(
    "\nDate range:", format(min(electronics_df$date), "%Y-%m-%d"),
    "to", format(max(electronics_df$date), "%Y-%m-%d"), "\n"
)

cat(
    "Index range:", min(electronics_df$value),
    "to", max(electronics_df$value), "\n"
)

missing_values <- colSums(is.na(electronics_df))
cat("\nMissing values by column:\n")
print(missing_values)
# Out:
# Dataset summary:
#       date                value
#  Min.   :1972-01-01   Min.   :  0.0286
#  1st Qu.:1985-04-08   1st Qu.:  0.1656
#  Median :1998-07-16   Median :  2.9628
#  Mean   :1998-07-17   Mean   : 31.0510
#  3rd Qu.:2011-10-24   3rd Qu.: 55.1786
#  Max.   :2025-02-01   Max.   :153.4738
#
# Date range: 1972-01-01 to 2025-02-01
# Index range: 0.0286 to 153.4738
#
# Missing values by column:
#  date value
#     0     0

# %%
# Plot the series
p1 <- ggplot(electronics_df, aes(x = date, y = value)) +
  geom_line(color = "#1F77B4") +
  labs(
    title = "Industrial Production: Computer and Electronic Products (1972-2024)",
    subtitle = "Index 2017=100, Seasonally Adjusted",
    x = "Date",
    y = "Index Value"
  ) +
  theme_tsa()

print(p1)
# Out:
# plot without title

# %%
# Highlight tech boom and bust periods
p2 <- ggplot(electronics_df, aes(x = date, y = value)) +
  geom_line(color = "#1F77B4") +
  geom_rect(
    aes(
      xmin = as.Date("1995-01-01"),
      xmax = as.Date("2000-03-31"),
      ymin = 0,
      ymax = Inf
    ),
    fill = "lightgreen", alpha = 0.2
  ) +
  geom_rect(
    aes(
      xmin = as.Date("2000-04-01"),
      xmax = as.Date("2002-12-31"),
      ymin = 0,
      ymax = Inf
    ),
    fill = "lightpink", alpha = 0.2
  ) +
  geom_rect(
    aes(
      xmin = as.Date("2008-01-01"),
      xmax = as.Date("2009-06-30"),
      ymin = 0,
      ymax = Inf
    ),
    fill = "lightpink", alpha = 0.2
  ) +
  annotate("text",
    x = as.Date("1997-06-01"), y = max(electronics_df$value) * 0.95,
    label = "Dot-Com Boom", color = "darkgreen", size = 5
  ) +
  annotate("text",
    x = as.Date("2001-06-15"), y = max(electronics_df$value) * 0.9,
    label = "Dot-Com Bust", color = "darkred", size = 5
  ) +
  annotate("text",
    x = as.Date("2008-06-01"), y = max(electronics_df$value) * 0.85,
    label = "Great Recession", color = "darkred", size = 5
  ) +
  labs(
    title = "Computer and Electronic Products Index with Key Periods Highlighted",
    x = "Date",
    y = "Index Value (2017=100)"
  ) +
  theme_tsa()

print(p2)
# Out:
# plot without title

# %%
# Create a monthly time series object
monthly_ts <- ts(electronics_df$value,
  frequency = 12,
  start = c(
    year(min(electronics_df$date)),
    month(min(electronics_df$date))
  )
)

# Plot the time series
autoplot(monthly_ts) +
  labs(
    title = "Computer and Electronic Products Index (Monthly)",
    x = "Time",
    y = "Index Value (2017=100)"
  ) +
  theme_tsa()
# Out:
# plot without title

# %%
# Determine optimal transformation with Box-Cox
lambda <- BoxCox.lambda(monthly_ts)
cat("Optimal lambda for Box-Cox transformation:", lambda, "\n")
if (abs(lambda) < 0.1) {
    cat("Lambda is close to 0, using log transformation\n")
    transformed_ts <- log(monthly_ts)
    transformation_label <- "Log Transformation"
} else {
    cat("Using Box-Cox transformation with lambda =", lambda, "\n")
    transformed_ts <- BoxCox(monthly_ts, lambda)
    transformation_label <- paste("Box-Cox Transformation (λ =", round(lambda, 4), ")")
}

transformed_df <- data.frame(
    Date = electronics_df$date,
    Original = as.numeric(monthly_ts),
    Transformed = as.numeric(transformed_ts)
)

# Plot original vs transformed
p_trans <- ggplot(transformed_df, aes(x = Date)) +
    geom_line(aes(y = Original, color = "Original"), linewidth = 0.8) +
    geom_line(aes(
        y = scale(Transformed) * sd(Original) + mean(Original),
        color = "Transformed (Scaled)"
    ), linewidth = 0.8) +
    labs(
        title = paste("Original vs", transformation_label),
        x = "Date", y = "Value",
        color = "Series"
    ) +
    scale_color_manual(values = c("Original" = "#1F77B4", "Transformed (Scaled)" = "#FF7F0E")) +
    theme_tsa()

print(p_trans)
# Out:
# Optimal lambda for Box-Cox transformation: -0.009282951
# Lambda is close to 0, using log transformation
# plot without title

# %%
# Test for stationarity using ADF test and KPSS test

adf_test <- adf.test(transformed_ts, alternative = "stationary")
kpss_test <- kpss.test(transformed_ts, null = "Trend")

cat("ADF Test for Stationarity:\n")
print(adf_test)

cat("\nKPSS Test for Stationarity:\n")
print(kpss_test)

cat("\nConclusion:\n")
if (adf_test$p.value < 0.05) {
    cat("ADF test rejects the null hypothesis, series is stationary\n")
} else {
    cat("ADF test fails to reject the null hypothesis, series is non-stationary\n")
}
if (kpss_test$p.value < 0.05) {
    cat("KPSS test rejects the null hypothesis, series is non-stationary\n")
} else {
    cat("KPSS test fails to reject the null hypothesis, series is stationary\n")
}
# Out:
# Warning message in kpss.test(transformed_ts, null = "Trend"):
# “p-value smaller than printed p-value”
# ADF Test for Stationarity:
#
# 	Augmented Dickey-Fuller Test
#
# data:  transformed_ts
# Dickey-Fuller = -0.80702, Lag order = 8, p-value = 0.961
# alternative hypothesis: stationary
#
#
# KPSS Test for Stationarity:
#
# 	KPSS Test for Trend Stationarity
#
# data:  transformed_ts
# KPSS Trend = 1.0482, Truncation lag parameter = 6, p-value = 0.01
#
#
# Conclusion:
# ADF test fails to reject the null hypothesis, series is non-stationary
# KPSS test rejects the null hypothesis, series is non-stationary

# %%
# Differencing to achieve stationarity
diff_ts <- diff(transformed_ts)

p_diff <- autoplot(diff_ts) +
    labs(
        title = "Differenced Transformed Series",
        x = "Time", y = "Change in Transformed Value"
    ) +
    theme_tsa()

print(p_diff)
# Out:
# plot without title

# %%
# retesting for stationarity after differencing

adf_test_diff <- adf.test(diff_ts, alternative = "stationary")
kpss_test_diff <- kpss.test(diff_ts, null = "Trend")

cat("ADF Test for Stationarity (After Differencing):\n")
print(adf_test_diff)

cat("\nKPSS Test for Stationarity (After Differencing):\n")
print(kpss_test_diff)

cat("\nConclusion (After Differencing):\n")
if (adf_test_diff$p.value < 0.05) {
    cat("ADF test rejects the null hypothesis, series is stationary\n")
} else {
    cat("ADF test fails to reject the null hypothesis, series is non-stationary\n")
}
if (kpss_test_diff$p.value < 0.05) {
    cat("KPSS test rejects the null hypothesis, series is non-stationary\n")
} else {
    cat("KPSS test fails to reject the null hypothesis, series is stationary\n")
}
# Out:
# Warning message in adf.test(diff_ts, alternative = "stationary"):
# “p-value smaller than printed p-value”
# Warning message in kpss.test(diff_ts, null = "Trend"):
# “p-value smaller than printed p-value”
# ADF Test for Stationarity (After Differencing):
#
# 	Augmented Dickey-Fuller Test
#
# data:  diff_ts
# Dickey-Fuller = -6.2411, Lag order = 8, p-value = 0.01
# alternative hypothesis: stationary
#
#
# KPSS Test for Stationarity (After Differencing):
#
# 	KPSS Test for Trend Stationarity
#
# data:  diff_ts
# KPSS Trend = 0.46956, Truncation lag parameter = 6, p-value = 0.01
#
#
# Conclusion (After Differencing):
# ADF test rejects the null hypothesis, series is stationary
# KPSS test rejects the null hypothesis, series is non-stationary

# %%
# ACF and PACF plots for differenced series
p_acf_diff <- ggAcf(diff_ts, lag = 36) +
    labs(
        title = "ACF of Differenced Series",
        x = "Lag", y = "ACF"
    ) +
    theme_tsa()

p_pacf_diff <- ggAcf(diff_ts, lag = 36, type = "partial") +
    labs(
        title = "PACF of Differenced Series",
        x = "Lag", y = "PACF"
    ) +
    theme_tsa()

grid.arrange(p_acf_diff, p_pacf_diff, ncol = 2)
# Out:
# plot without title

# %%
# Model identification using armasubsets
subset_results <- armasubsets(y = diff_ts, nar = 10, nma = 10,
                              ar.method = "ols")

# Plot results
par(bg = "white")
plot(subset_results, which = "bic", main = "ARMA Model Selection by BIC",
     xlab = "AR and MA terms", ylab = "BIC", cex.axis = 1, cex.lab = 1)
# Out:
# Plot with title “ARMA Model Selection by BIC”

# %% [markdown]
# **Top 5 models using armasubsets() :**
# - ARIMA(4,1,3)
# - ARIMA(4,1,6)
# - ARIMA(4,1,1)
# - ARIMA(4,1,10)
# - ARIMA(8,1,10)

# %%
# Grid search for best ARIMA models
max_p <- 10
max_q <- 10
d <- 1

aic_values <- matrix(NA, nrow = max_p + 1, ncol = max_q + 1)
bic_values <- matrix(NA, nrow = max_p + 1, ncol = max_q + 1)

cat("\nFitting ARIMA models with different orders...\n")
for (p in 0:max_p) {
  for (q in 0:max_q) {
    if (p == 0 && q == 0) next
    
    cat(sprintf("Fitting ARIMA(%d,%d,%d)...\n", p, d, q))
    
    tryCatch({
      # Using transformed_ts instead of monthly_ts
      model <- Arima(transformed_ts, order = c(p, d, q))
      aic_values[p+1, q+1] <- model$aic
      bic_values[p+1, q+1] <- model$bic
    }, error = function(e) {
      cat("  Error:", e$message, "\n")
    })
  }
}

model_data <- data.frame(
  p = rep(0:max_p, each = max_q + 1),
  q = rep(0:max_q, max_p + 1),
  AIC = as.vector(aic_values),
  BIC = as.vector(bic_values)
)

model_data <- model_data[!is.na(model_data$AIC) & !is.na(model_data$BIC), ]
model_data$Model <- paste0("(", model_data$p, ",1,", model_data$q, ")")

best_aic_model <- model_data[which.min(model_data$AIC), ]
best_bic_model <- model_data[which.min(model_data$BIC), ]

cat("\nBest model by AIC: ARIMA", best_aic_model$Model, "with AIC =", round(best_aic_model$AIC, 2), "\n")
cat("Best model by BIC: ARIMA", best_bic_model$Model, "with BIC =", round(best_bic_model$BIC, 2), "\n")
# Out:
# Fitting ARIMA models with different orders...
# Fitting ARIMA(0,1,1)...
# Fitting ARIMA(0,1,2)...
# Fitting ARIMA(0,1,3)...
# Fitting ARIMA(0,1,4)...
# Fitting ARIMA(0,1,5)...
# Fitting ARIMA(0,1,6)...
# Fitting ARIMA(0,1,7)...
# Fitting ARIMA(0,1,8)...
# Fitting ARIMA(0,1,9)...
# Fitting ARIMA(0,1,10)...
# Fitting ARIMA(1,1,0)...
# Fitting ARIMA(1,1,1)...
# Fitting ARIMA(1,1,2)...
# Fitting ARIMA(1,1,3)...
# Fitting ARIMA(1,1,4)...
# Fitting ARIMA(1,1,5)...
# Fitting ARIMA(1,1,6)...
# Fitting ARIMA(1,1,7)...
# Fitting ARIMA(1,1,8)...
# Fitting ARIMA(1,1,9)...
# Fitting ARIMA(1,1,10)...
# Fitting ARIMA(2,1,0)...
# Fitting ARIMA(2,1,1)...
# Fitting ARIMA(2,1,2)...
# Fitting ARIMA(2,1,3)...
# Fitting ARIMA(2,1,4)...
# Fitting ARIMA(2,1,5)...
# Fitting ARIMA(2,1,6)...
# Fitting ARIMA(2,1,7)...
# Fitting ARIMA(2,1,8)...
# Fitting ARIMA(2,1,9)...
# Fitting ARIMA(2,1,10)...
# Fitting ARIMA(3,1,0)...
# Fitting ARIMA(3,1,1)...
# Fitting ARIMA(3,1,2)...
# Fitting ARIMA(3,1,3)...
# Fitting ARIMA(3,1,4)...
# Fitting ARIMA(3,1,5)...
# Fitting ARIMA(3,1,6)...
# Fitting ARIMA(3,1,7)...
# Fitting ARIMA(3,1,8)...
# Fitting ARIMA(3,1,9)...
# Fitting ARIMA(3,1,10)...
# Fitting ARIMA(4,1,0)...
# Fitting ARIMA(4,1,1)...
# Fitting ARIMA(4,1,2)...
# Fitting ARIMA(4,1,3)...
# Fitting ARIMA(4,1,4)...
# Fitting ARIMA(4,1,5)...
# Fitting ARIMA(4,1,6)...
# Fitting ARIMA(4,1,7)...
# Fitting ARIMA(4,1,8)...
# Fitting ARIMA(4,1,9)...
# Fitting ARIMA(4,1,10)...
# Fitting ARIMA(5,1,0)...
# Fitting ARIMA(5,1,1)...
# Fitting ARIMA(5,1,2)...
# Fitting ARIMA(5,1,3)...
# Fitting ARIMA(5,1,4)...
# Fitting ARIMA(5,1,5)...
# Fitting ARIMA(5,1,6)...
# Fitting ARIMA(5,1,7)...
# Fitting ARIMA(5,1,8)...
# Fitting ARIMA(5,1,9)...
# Fitting ARIMA(5,1,10)...
# Fitting ARIMA(6,1,0)...
# Fitting ARIMA(6,1,1)...
# Fitting ARIMA(6,1,2)...
# Fitting ARIMA(6,1,3)...
# Fitting ARIMA(6,1,4)...
# Fitting ARIMA(6,1,5)...
# Fitting ARIMA(6,1,6)...
# Fitting ARIMA(6,1,7)...
# Fitting ARIMA(6,1,8)...
# Fitting ARIMA(6,1,9)...
# Fitting ARIMA(6,1,10)...
# Fitting ARIMA(7,1,0)...
# Fitting ARIMA(7,1,1)...
# Fitting ARIMA(7,1,2)...
# Fitting ARIMA(7,1,3)...
# Fitting ARIMA(7,1,4)...
# Fitting ARIMA(7,1,5)...
# Fitting ARIMA(7,1,6)...
# Fitting ARIMA(7,1,7)...
# Fitting ARIMA(7,1,8)...
# Fitting ARIMA(7,1,9)...
# Fitting ARIMA(7,1,10)...
# Fitting ARIMA(8,1,0)...
# Fitting ARIMA(8,1,1)...
# Fitting ARIMA(8,1,2)...
# Fitting ARIMA(8,1,3)...
# Fitting ARIMA(8,1,4)...
# Fitting ARIMA(8,1,5)...
# Fitting ARIMA(8,1,6)...
# Fitting ARIMA(8,1,7)...
# Fitting ARIMA(8,1,8)...
# Fitting ARIMA(8,1,9)...
# Fitting ARIMA(8,1,10)...
# Fitting ARIMA(9,1,0)...
# Fitting ARIMA(9,1,1)...
# Fitting ARIMA(9,1,2)...
# Fitting ARIMA(9,1,3)...
# Fitting ARIMA(9,1,4)...
# Fitting ARIMA(9,1,5)...
# Fitting ARIMA(9,1,6)...
# Fitting ARIMA(9,1,7)...
# Fitting ARIMA(9,1,8)...
# Fitting ARIMA(9,1,9)...
# Fitting ARIMA(9,1,10)...
# Fitting ARIMA(10,1,0)...
# Fitting ARIMA(10,1,1)...
# Fitting ARIMA(10,1,2)...
# Fitting ARIMA(10,1,3)...
# Fitting ARIMA(10,1,4)...
# Fitting ARIMA(10,1,5)...
# Fitting ARIMA(10,1,6)...
# Fitting ARIMA(10,1,7)...
# Fitting ARIMA(10,1,8)...
# Fitting ARIMA(10,1,9)...
# Fitting ARIMA(10,1,10)...
#
# Best model by AIC: ARIMA (5,1,9) with AIC = -3340.64
# Best model by BIC: ARIMA (1,1,1) with BIC = -3301.95

# %% [markdown]
# **The best models using grid search are:**
# - Best model by AIC: ARIMA (5,1,9) with AIC = -3340.64
# - Best model by AIC: ARIMA (5,1,9) with AIC = -3340.64

# %%
# Split data for training and testing
n_months <- length(transformed_ts)
train_end <- n_months - 24  # Use last 24 months for testing

train_ts <- window(transformed_ts, end = c(time(transformed_ts)[train_end]))
test_ts <- window(transformed_ts, start = c(time(transformed_ts)[train_end + 1]))

# Define candidate models from both selection methods
candidate_models <- list(
  list(p=4, d=1, q=3, name="ARIMA(4,1,3) - Top ARMASUBSETS Model"),
  list(p=4, d=1, q=6, name="ARIMA(4,1,6) - Top ARMASUBSETS Model"),
  list(p=4, d=1, q=1, name="ARIMA(4,1,1) - Top ARMASUBSETS Model"),
  list(p=4, d=1, q=10, name="ARIMA(4,1,10) - Top ARMASUBSETS Model"),
  list(p=8, d=1, q=10, name="ARIMA(8,1,10) - Top ARMASUBSETS Model"),
  list(p=5, d=1, q=9, name="ARIMA(5,1,9) - Best AIC & BIC (Grid Search)")
)
# Remove duplicates if any
unique_models <- list()
model_names <- character()
for (model in candidate_models) {
  model_key <- paste(model$p, model$d, model$q)
  if (!(model_key %in% names(unique_models))) {
    unique_models[[model_key]] <- model
    model_names <- c(model_names, model$name)
  }
}
candidate_models <- unique_models

# Fit models and evaluate forecasts
forecast_results <- data.frame(
  Model = character(),
  RMSE = numeric(),
  MAE = numeric(),
  MAPE = numeric(),
  stringsAsFactors = FALSE
)

fitted_models <- list()

for (model_key in names(candidate_models)) {
  model <- candidate_models[[model_key]]
  model_name <- model$name
  p <- model$p
  d <- model$d
  q <- model$q
  
  cat(sprintf("\nFitting %s...\n", model_name))
  
  tryCatch({
    # Fit model
    arima_model <- Arima(train_ts, order = c(p, d, q))
    fitted_models[[model_name]] <- arima_model
    
    # Generate forecasts
    h <- length(test_ts)
    forecasts <- forecast(arima_model, h = h)
    
    # Calculate error metrics
    errors <- test_ts - forecasts$mean
    rmse <- sqrt(mean(errors^2))
    mae <- mean(abs(errors))
    mape <- mean(abs(errors / test_ts)) * 100
    
    cat(sprintf("RMSE: %.4f, MAE: %.4f, MAPE: %.2f%%\n", rmse, mae, mape))
    
    # Add to results
    forecast_results <- rbind(forecast_results, data.frame(
      Model = model_name,
      RMSE = rmse,
      MAE = mae,
      MAPE = mape
    ))
    
  }, error = function(e) {
    cat("  Error:", e$message, "\n")
  })
}

# Sort by RMSE
forecast_results <- forecast_results[order(forecast_results$RMSE), ]
rownames(forecast_results) <- NULL

cat("\nOut-of-sample forecast accuracy comparison:\n")
print(forecast_results)

# Identify best model
best_model_name <- forecast_results$Model[1]
cat("\nBest model based on forecast accuracy (RMSE):", best_model_name, "\n")
# Out:
# Fitting ARIMA(4,1,3) - Top ARMASUBSETS Model...
# RMSE: 0.0358, MAE: 0.0255, MAPE: 0.51%
#
# Fitting ARIMA(4,1,6) - Top ARMASUBSETS Model...
# RMSE: 0.0329, MAE: 0.0241, MAPE: 0.49%
#
# Fitting ARIMA(4,1,1) - Top ARMASUBSETS Model...
# RMSE: 0.0354, MAE: 0.0259, MAPE: 0.52%
#
# Fitting ARIMA(4,1,10) - Top ARMASUBSETS Model...
# RMSE: 0.0214, MAE: 0.0175, MAPE: 0.36%
#
# Fitting ARIMA(8,1,10) - Top ARMASUBSETS Model...
# RMSE: 0.0231, MAE: 0.0195, MAPE: 0.40%
#
# Fitting ARIMA(5,1,9) - Best AIC & BIC (Grid Search)...
# RMSE: 0.0206, MAE: 0.0171, MAPE: 0.35%
#
# Out-of-sample forecast accuracy comparison:
#                                         Model       RMSE        MAE      MAPE
# 1 ARIMA(5,1,9) - Best AIC & BIC (Grid Search) 0.02063542 0.01707367 0.3466193
# 2       ARIMA(4,1,10) - Top ARMASUBSETS Model 0.02143464 0.01748848 0.3550584
# 3       ARIMA(8,1,10) - Top ARMASUBSETS Model 0.02306258 0.01948126 0.3957667
# 4        ARIMA(4,1,6) - Top ARMASUBSETS Model 0.03285730 0.02410346 0.4856027
# 5        ARIMA(4,1,1) - Top ARMASUBSETS Model 0.03542115 0.02591491 0.5219978
# 6        ARIMA(4,1,3) - Top ARMASUBSETS Model 0.03576203 0.02546096 0.5125242
#
# Best model based on forecast accuracy (RMSE): ARIMA(5,1,9) - Best AIC & BIC (Grid Search)

# %%
# Refit best model on full transformed data
p <- as.numeric(gsub(".*\\(([0-9]+),1,([0-9]+).*", "\\1", best_model_name))
q <- as.numeric(gsub(".*\\(([0-9]+),1,([0-9]+).*", "\\2", best_model_name))

final_model <- Arima(transformed_ts, order = c(p, 1, q))

# Check residuals
checkresiduals(final_model)

# Plot residuals
residuals_df <- data.frame(
  Date = electronics_df$date[(length(electronics_df$date) - length(residuals(final_model)) + 1):length(electronics_df$date)],
  Residuals = residuals(final_model)
)

# qq plot
p_qq <- ggplot(residuals_df, aes(sample = Residuals)) +
  stat_qq() +
  stat_qq_line(color = "red") +
  labs(
    title = "QQ Plot of Residuals",
    x = "Theoretical Quantiles",
    y = "Sample Quantiles"
  ) +
  theme_tsa()
print(p_qq)

# Normality test
shapiro_test <- shapiro.test(residuals(final_model))
cat("\nShapiro-Wilk test for normality:\n")
print(shapiro_test)
cat("Interpretation: p-value", ifelse(shapiro_test$p.value > 0.05, 
    "> 0.05, residuals appear normally distributed", 
    "< 0.05, residuals not normally distributed"), "\n")

# Ljung-Box test for autocorrelation
lb_test <- Box.test(residuals(final_model), lag = 12, type = "Ljung-Box")
cat("\nLjung-Box test for autocorrelation:\n")
print(lb_test)
cat("Interpretation: p-value", ifelse(lb_test$p.value > 0.05, 
    "> 0.05, no significant autocorrelation remains", 
    "< 0.05, significant autocorrelation remains"), "\n")

# ARCH test for heteroskedasticity
arch_test <- ArchTest(residuals(final_model), lags = 12)
cat("\nARCH test for conditional heteroskedasticity:\n")
print(arch_test)
cat("Interpretation: p-value", ifelse(arch_test$p.value > 0.05, 
    "> 0.05, no significant ARCH effects detected", 
    "< 0.05, ARCH effects present"), "\n")

# Runs test for randomness
runs_test <- runs.test(residuals(final_model) > 0)
cat("\nRuns test for randomness:\n")
print(runs_test)
cat("Interpretation: p-value", ifelse(runs_test$p.value > 0.05, 
    "> 0.05, residuals appear random", 
    "< 0.05, residuals may not be random"), "\n")
# Out:
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(4,1,3)
# Q* = 47.507, df = 17, p-value = 0.0001021
#
# Model df: 7.   Total lags used: 24
# Don't know how to automatically pick scale for object of type <ts>. Defaulting
# to continuous.
# Don't know how to automatically pick scale for object of type <ts>. Defaulting
# to continuous.
# plot without title
# Shapiro-Wilk test for normality:
#
# 	Shapiro-Wilk normality test
#
# data:  residuals(final_model)
# W = 0.95915, p-value = 2.555e-12
#
# Interpretation: p-value < 0.05, residuals not normally distributed
#
# Ljung-Box test for autocorrelation:
#
# 	Box-Ljung test
#
# data:  residuals(final_model)
# X-squared = 12.782, df = 12, p-value = 0.3851
#
# Interpretation: p-value > 0.05, no significant autocorrelation remains
#
# ARCH test for conditional heteroskedasticity:
#
# 	ARCH LM-test; Null hypothesis: no ARCH effects
#
# data:  residuals(final_model)
# Chi-squared = 131.31, df = 12, p-value < 2.2e-16
#
# Interpretation: p-value < 0.05, ARCH effects present
#
# Runs test for randomness:
#
# 	Runs Test - Two sided
#
# data:  residuals(final_model) > 0
# Standardized Runs Statistic = NaN, p-value = NA
#
# Interpretation: p-value NA
# plot without title
